# %% [markdown]
# # Name: Sheikh Nabil
# ## The Sparks Foundation: Data Science and Business Analytics Internship
# ### Task 8: Timeline Analysis (Covid-19)
# ● Analyze Data showing spread of Covid-19 cases in your country or any region (Asia, Europe, BRICS etc)
#
# ● Identify interesting patterns and possible reasons helping Covid-19 spread with basic as well as advanced charts
#
# Dataset: https://bit.ly/30d2gdi

# %% [markdown]
# ## Import Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pylab as pl
import seaborn as sns
# %matplotlib inline
sns.set()

# %%
df = pd.read_csv("owid-covid-data.csv")

# %%
df.head(10)
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 1      AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
# 2      AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 3      AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4      AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
# 5      AFG      Asia  Afghanistan  2020-01-08          NaN        0.0
# 6      AFG      Asia  Afghanistan  2020-01-09          NaN        0.0
# 7      AFG      Asia  Afghanistan  2020-01-10          NaN        0.0
# 8      AFG      Asia  Afghanistan  2020-01-11          NaN        0.0
# 9      AFG      Asia  Afghanistan  2020-01-12          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
# 5                 0.0           NaN         0.0                  0.0  ...
# 6                 0.0           NaN         0.0                  0.0  ...
# 7                 0.0           NaN         0.0                  0.0  ...
# 8                 0.0           NaN         0.0                  0.0  ...
# 9                 0.0           NaN         0.0                  0.0  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0           NaN                  37.746                         0.5
# 1           NaN                  37.746                         0.5
# 2           NaN                  37.746                         0.5
# 3           NaN                  37.746                         0.5
# 4           NaN                  37.746                         0.5
# 5           NaN                  37.746                         0.5
# 6           NaN                  37.746                         0.5
# 7           NaN                  37.746                         0.5
# 8           NaN                  37.746                         0.5
# 9           NaN                  37.746                         0.5
#
#    life_expectancy  human_development_index  population  \
# 0            64.83                    0.511  41128772.0
# 1            64.83                    0.511  41128772.0
# 2            64.83                    0.511  41128772.0
# 3            64.83                    0.511  41128772.0
# 4            64.83                    0.511  41128772.0
# 5            64.83                    0.511  41128772.0
# 6            64.83                    0.511  41128772.0
# 7            64.83                    0.511  41128772.0
# 8            64.83                    0.511  41128772.0
# 9            64.83                    0.511  41128772.0
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
# 5                                   NaN                          NaN
# 6                                   NaN                          NaN
# 7                                   NaN                          NaN
# 8                                   NaN                          NaN
# 9                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN
# 5               NaN                                      NaN
# 6               NaN                                      NaN
# 7               NaN                                      NaN
# 8               NaN                                      NaN
# 9               NaN                                      NaN
#
# [10 rows x 67 columns]

# %%
df.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed  total_deaths  \
# count  2.633540e+05  2.906040e+05        2.893400e+05  2.432290e+05
# mean   5.423132e+06  1.110653e+04        1.115202e+04  7.821417e+04
# std    3.405955e+07  1.048646e+05        1.022032e+05  4.058042e+05
# min    1.000000e+00  0.000000e+00        0.000000e+00  1.000000e+00
# 25%    6.091000e+03  0.000000e+00        1.286000e+00  1.160000e+02
# 50%    5.866550e+04  2.000000e+01        4.114300e+01  1.163000e+03
# 75%    6.070298e+05  5.640000e+02        6.635710e+02  1.019200e+04
# max    7.614015e+08  7.946354e+06        6.402146e+06  6.886987e+06
#
#           new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  290686.000000        289456.000000            263354.000000
# mean       98.990467            99.381680             82882.753718
# std       610.463653           600.953399            133002.421636
# min         0.000000             0.000000                 0.000000
# 25%         0.000000             0.000000              1828.126000
# 50%         0.000000             0.286000             18604.522500
# 75%         6.000000             7.000000             99190.921250
# max     20005.000000         14581.286000            730701.881000
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count          290604.000000                   289340.000000
# mean              167.451019                      168.125742
# std              1147.575425                      646.271440
# min                 0.000000                        0.000000
# 25%                 0.000000                        0.316000
# 50%                 2.938000                       11.709500
# 75%                74.120000                      110.136750
# max            228872.025000                    37241.781000
#
#        total_deaths_per_million  ...   male_smokers  handwashing_facilities  \
# count             243229.000000  ...  171415.000000           113478.000000
# mean                 785.938076  ...      32.909972               50.790118
# std                 1033.880973  ...      13.574375               31.957293
# min                    0.000000  ...       7.700000                1.188000
# 25%                   47.143000  ...      22.600000               20.859000
# 50%                  315.636000  ...      33.100000               49.839000
# 75%                 1192.778000  ...      41.300000               83.241000
# max                 6453.558000  ...      78.100000              100.000000
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# count               204511.000000    274976.000000            224574.000000
# mean                     3.097192        73.718558                 0.722482
# std                      2.548464         7.397295                 0.148991
# min                      0.100000        53.280000                 0.394000
# 25%                      1.300000        69.590000                 0.602000
# 50%                      2.500000        75.050000                 0.740000
# 75%                      4.200000        79.460000                 0.829000
# max                     13.800000        86.750000                 0.957000
#
#          population  excess_mortality_cumulative_absolute  \
# count  2.990260e+05                          1.029500e+04
# mean   1.280985e+08                          4.727286e+04
# std    6.596486e+08                          1.377826e+05
# min    4.700000e+01                         -3.772610e+04
# 25%    4.490020e+05                          2.185000e+01
# 50%    5.882259e+06                          4.464499e+03
# 75%    2.830170e+07                          3.174990e+04
# max    7.975105e+09                          1.282260e+06
#
#        excess_mortality_cumulative  excess_mortality  \
# count                 10295.000000      10295.000000
# mean                      9.535368         12.996518
# std                      13.082029         26.634303
# min                     -44.230000        -95.920000
# 25%                       0.420000         -1.040000
# 50%                       7.750000          6.750000
# 75%                      15.520000         18.545000
# max                      76.550000        377.040000
#
#        excess_mortality_cumulative_per_million
# count                             10295.000000
# mean                               1453.830857
# std                                1830.272458
# min                               -1984.281600
# 25%                                  15.453504
# 50%                                 881.367860
# 75%                                2372.123350
# max                               10329.523000
#
# [8 rows x 62 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299026 entries, 0 to 299025
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    299026 non-null  object
#  1   continent                                   284833 non-null  object
#  2   location                                    299026 non-null  object
#  3   date                                        299026 non-null  object
#  4   total_cases                                 263354 non-null  float64
#  5   new_cases                                   290604 non-null  float64
#  6   new_cases_smoothed                          289340 non-null  float64
#  7   total_deaths                                243229 non-null  float64
#  8   new_deaths                                  290686 non-null  float64
#  9   new_deaths_smoothed                         289456 non-null  float64
#  10  total_cases_per_million                     263354 non-null  float64
#  11  new_cases_per_million                       290604 non-null  float64
#  12  new_cases_smoothed_per_million              289340 non-null  float64
#  13  total_deaths_per_million                    243229 non-null  float64
#  14  new_deaths_per_million                      290686 non-null  float64
#  15  new_deaths_smoothed_per_million             289456 non-null  float64
#  16  reproduction_rate                           184817 non-null  float64
#  17  icu_patients                                34538 non-null   float64
#  18  icu_patients_per_million                    34538 non-null   float64
#  19  hosp_patients                               34892 non-null   float64
#  20  hosp_patients_per_million                   34892 non-null   float64
#  21  weekly_icu_admissions                       8989 non-null    float64
#  22  weekly_icu_admissions_per_million           8989 non-null    float64
#  23  weekly_hosp_admissions                      21129 non-null   float64
#  24  weekly_hosp_admissions_per_million          21129 non-null   float64
#  25  total_tests                                 79387 non-null   float64
#  26  new_tests                                   75403 non-null   float64
#  27  total_tests_per_thousand                    79387 non-null   float64
#  28  new_tests_per_thousand                      75403 non-null   float64
#  29  new_tests_smoothed                          103965 non-null  float64
#  30  new_tests_smoothed_per_thousand             103965 non-null  float64
#  31  positive_rate                               95927 non-null   float64
#  32  tests_per_case                              94348 non-null   float64
#  33  tests_units                                 106788 non-null  object
#  34  total_vaccinations                          73700 non-null   float64
#  35  people_vaccinated                           70587 non-null   float64
#  36  people_fully_vaccinated                     68273 non-null   float64
#  37  total_boosters                              42466 non-null   float64
#  38  new_vaccinations                            60895 non-null   float64
#  39  new_vaccinations_smoothed                   161398 non-null  float64
#  40  total_vaccinations_per_hundred              73700 non-null   float64
#  41  people_vaccinated_per_hundred               70587 non-null   float64
#  42  people_fully_vaccinated_per_hundred         68273 non-null   float64
#  43  total_boosters_per_hundred                  42466 non-null   float64
#  44  new_vaccinations_smoothed_per_million       161398 non-null  float64
#  45  new_people_vaccinated_smoothed              161489 non-null  float64
#  46  new_people_vaccinated_smoothed_per_hundred  161489 non-null  float64
#  47  stringency_index                            193194 non-null  float64
#  48  population_density                          253717 non-null  float64
#  49  median_age                                  235970 non-null  float64
#  50  aged_65_older                               227713 non-null  float64
#  51  aged_70_older                               233605 non-null  float64
#  52  gdp_per_capita                              231259 non-null  float64
#  53  extreme_poverty                             148953 non-null  float64
#  54  cardiovasc_death_rate                       231679 non-null  float64
#  55  diabetes_prevalence                         243487 non-null  float64
#  56  female_smokers                              173779 non-null  float64
#  57  male_smokers                                171415 non-null  float64
#  58  handwashing_facilities                      113478 non-null  float64
#  59  hospital_beds_per_thousand                  204511 non-null  float64
#  60  life_expectancy                             274976 non-null  float64
#  61  human_development_index                     224574 non-null  float64
#  62  population                                  299026 non-null  float64
#  63  excess_mortality_cumulative_absolute        10295 non-null   float64
#  64  excess_mortality_cumulative                 10295 non-null   float64
#  65  excess_mortality                            10295 non-null   float64
#  66  excess_mortality_cumulative_per_million     10295 non-null   float64
# dtypes: float64(62), object(5)
# memory usage: 152.9+ MB

# %%
df.shape
# Out:
# (299026, 67)

# %%
duplicate_rows_df = df[df.duplicated()]
print("Number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# Number of duplicate rows:  (0, 67)

# %%
df.count()
# Out:
# iso_code                                   299026
# continent                                  284833
# location                                   299026
# date                                       299026
# total_cases                                263354
#                                             ...
# population                                 299026
# excess_mortality_cumulative_absolute        10295
# excess_mortality_cumulative                 10295
# excess_mortality                            10295
# excess_mortality_cumulative_per_million     10295
# Length: 67, dtype: int64

# %% [markdown]
# ## Checking the Missing or Null values

# %%
print(df.isnull().sum())
# Out:
# iso_code                                        0
# continent                                   14193
# location                                        0
# date                                            0
# total_cases                                 35672
#                                             ...
# population                                      0
# excess_mortality_cumulative_absolute       288731
# excess_mortality_cumulative                288731
# excess_mortality                           288731
# excess_mortality_cumulative_per_million    288731
# Length: 67, dtype: int64

# %%
df1 = df[["date", "total_cases", "new_cases", "total_deaths", "new_tests", "total_tests"]]
df1.head()
# Out:
#          date  total_cases  new_cases  total_deaths  new_tests  total_tests
# 0  2020-01-03          NaN        0.0           NaN        NaN          NaN
# 1  2020-01-04          NaN        0.0           NaN        NaN          NaN
# 2  2020-01-05          NaN        0.0           NaN        NaN          NaN
# 3  2020-01-06          NaN        0.0           NaN        NaN          NaN
# 4  2020-01-07          NaN        0.0           NaN        NaN          NaN

# %%
df1.date = pd.to_datetime(df.date)
df1.set_index('date', inplace = True)
df1.head()
df1.tail()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_17284\2056047410.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.date = pd.to_datetime(df.date)
#             total_cases  new_cases  total_deaths  new_tests  total_tests
# date
# 2023-03-25     264508.0        4.0        5679.0        NaN          NaN
# 2023-03-26     264509.0        1.0        5679.0        NaN          NaN
# 2023-03-27     264511.0        2.0        5679.0        NaN          NaN
# 2023-03-28     264511.0        0.0        5679.0        NaN          NaN
# 2023-03-29     264511.0        0.0        5679.0        NaN          NaN

# %%
df1.plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month', fontsize = 20)
# Out:
# Text(0.5, 0, 'Month')

# %%
df1.total_cases.plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month', fontsize = 20)
# Out:
# Text(0.5, 0, 'Month')

# %%
df1.new_cases.plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month', fontsize = 20)
# Out:
# Text(0.5, 0, 'Month')

# %%
df1.total_deaths.plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month', fontsize = 20)
# Out:
# Text(0.5, 0, 'Month')

# %%
df1.new_tests.plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month', fontsize = 20)
# Out:
# Text(0.5, 0, 'Month')

# %%
df1.total_tests.plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month', fontsize = 20)
# Out:
# Text(0.5, 0, 'Month')

# %% [markdown]
# ## Trends and Seasonality in TimeSeries Data

# %%
total_cases = df1[['total_cases']]
total_cases.rolling(12).mean().plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month' , fontsize = 20);

# %%
new_cases = df1[['new_cases']]
new_cases.rolling(12).mean().plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month' , fontsize = 20);

# %%
total_deaths = df1[['total_deaths']]
total_deaths.rolling(12).mean().plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month' , fontsize = 20);

# %%
new_tests = df1[['new_tests']]
new_tests.rolling(12).mean().plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month' , fontsize = 20);

# %%
total_tests = df1[['total_tests']]
total_tests.rolling(12).mean().plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month' , fontsize = 20);

# %%
total_cases = df1[['total_cases']]
total_cases.rolling(12).mean().plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month' , fontsize = 20);

# %% [markdown]
# # Thank You
